# %% [markdown]
# # Using spaCy for Luxembourgish
#
# 20.7.2023: Update for spaCy 3.6
#
# Since spaCy version 2.2.2 basic support for Luxembourgish (lb) has been implemented.
#
# Based on a few Luxembourgish examples, this notebook will illustrates some basic funtions. So far, the following  should work:
#
#  - tokenisation
#  - lemmatisation
#  - POS tagging (language model needed)
#  - stopword detection

# %%
# install spaCy (>= 2.2.2)
# !python3 -m pip install -U spacy

# install spacy-lookup-data (needed for lemmatisation; Luxembourgish lemmatisation data is included)
# !python3 -m pip install -U spacy-lookups-data
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/site-packages (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.11/site-packages (from spacy) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/site-packages (from spacy) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.11/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.11/site-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.11/site-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.11/site-packages (from spacy) (1.10.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/site-packages (from spacy) (67.6.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->spacy) (2.1.3)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Requirement already satisfied: spacy-lookups-data in /usr/local/lib/python3.11/site-packages (1.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/site-packages (from spacy-lookups-data) (67.6.1)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %% [markdown]
# ## Load the spaCy module and import the Luxembourgish pipeline

# %%
import spacy
from spacy import lang
# you need spaCy version >= 2.2.2
from spacy.lang.lb import Luxembourgish

# %% [markdown]
# ## Basic tokenisation of text
#
# This works out of the box without a pretrained model.

# %%
# Create the nlp object
nlp = Luxembourgish()

# Process a text
doc = nlp("fänke mer mam groupsspapp un, e grousspapp ass ëmmer e gudden ufank.")

# list tokens + token index
for token in doc:
    print('"' + token.text + '"', token.idx)
# Out:
# "fänke" 0
# "mer" 6
# "mam" 10
# "groupsspapp" 14
# "un" 26
# "," 28
# "e" 30
# "grousspapp" 32
# "ass" 43
# "ëmmer" 47
# "e" 53
# "gudden" 55
# "ufank" 62
# "." 67

# %% [markdown]
# ## POS tagging and further annotation
#
# In order to use POS tagging, a language model is needed. spaCy is not yet providing a model for Luxembourgish (see [here](https://spacy.io/usage/training) on how to train custom models). I've trained an model with own training data, which is available in this repository.

# %%
# load the language model

nlp = spacy.load("./lux-tagger-July2023/model-best/")
print("Pipeline:", nlp.pipe_names)
# Out:
# Pipeline: ['tok2vec', 'tagger']

# %%
# some Luxembourgish example texts to play with for POS tagging

doc = nlp(u"Zanter 1977 gëtt den Terrain vun der \"Lentille Terres Rouges\" net méi exploitéiert. De Projet \"Rout Lëns\" soll dem Site neit Liewen anhauchen. Zu Esch soll tëscht der Rue d'Audun an der Rue Barbourg en neie Quartier entstoe mat Wunnengen, Büroen, Butteker, klenge Firmen, Restauranten, Caféen, enger zentraler Plaz an engem ënnerierdesche Parkhaus. Déi historesch Valeur vum Site soll dobäi net zerstéiert ginn. Op ronn 11 Hektar soll de Quartier \"Rout Lëns\" en neien Espace public mat ville Gréngfläche ginn, dee Commerce, Schaffen a Liewe matenee verbënnt. A well dat Ganzt am Respekt an der Valorisatioun vun der industrieller Patrimoine soll entstoen, solle verschidden al Gebaier och net ofgerappt, mä bestoe bleiwen an an de Projet integréiert ginn. Erhale bleiwen déi al Turbinnenhal, d'Gebléishal, d'Lager, dat fréiert Stellwierk, sou wéi déi al stenge Mauer laanscht d'Rue d'Audun. RTL NEWS: De Projet gouf virgestallt. Den neie Quartier soll
# %%
# print results from POS tagging
# token   lemma    POS   stopword?   punct?   space?   shape

for token in doc:
    print("{0}\t{1}\t{2}\t{3}\t{4}\t{5}\t{6}\t{7}".format(
        token.text,
        token.lemma_,
        token.tag_,
        token.is_stop,
        token.is_punct,
        token.is_space,
        token.shape_,
        token.is_alpha
    ))
# Out:
# Zanter		N	True	False	False	Xxxxx	True
# 1977		NUM	False	False	False	dddd	False
# gëtt		AUX	True	False	False	xxxx	True
# den		D	True	False	False	xxx	True
# Terrain		N	False	False	False	Xxxxx	True
# vun		APPR	True	False	False	xxx	True
# der		D	True	False	False	xxx	True
# "		$	False	True	False	"	False
# Lentille		N	False	False	False	Xxxxx	True
# Terres		N	False	False	False	Xxxxx	True
# Rouges		N	False	False	False	Xxxxx	True
# "		$	False	True	False	"	False
# net		PTK	True	False	False	xxx	True
# méi		AV	True	False	False	xxx	True
# exploitéiert		V	False	False	False	xxxx	True
# .		$	False	True	False	.	False
# De		D	True	False	False	Xx	True
# Projet		N	False	False	False	Xxxxx	True
# "		$	False	True	False	"	False
# Rout		N	False	False	False	Xxxx	True
# Lëns		N	False	False	False	Xxxx	True
# "		$	False	True	False	"	False
# soll		MV	False	False	False	xxxx	True
# dem		D	True	False	False	xxx	True
# Site		N	False	False	False	Xxxx	True
# neit		ADJ	False	False	False	xxxx	True
# Liewen		N	False	False	False	Xxxxx	True
# anhauchen		V	False	False	False	xxxx	True
# .		$	False	True	False	.	False
# Zu		APPR	True	False	False	Xx	True
# Esch		N	False	False	False	Xxxx	True
# soll		MV	False	False	False	xxxx	True
# tëscht		APPR	True	False	False	xxxx	True
# der		D	True	False	False	xxx	True
# Rue		N	False	False	False	Xxx	True
# d'		D	True	False	False	x'	False
# Audun		N	False	False	False	Xxxxx	True
# an		APPR	True	False	False	xx	True
# der		D	True	False	False	xxx	True
# Rue		N	False	False	False	Xxx	True
# Barbourg		N	False	False	False	Xxxxx	True
# en		D	True	False	False	xx	True
# neie		ADJ	False	False	False	xxxx	True
# Quartier		N	False	False	False	Xxxxx	True
# entstoe		V	False	False	False	xxxx	True
# mat		APPR	True	False	False	xxx	True
# Wunnengen		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# Büroen		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# Butteker		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# klenge		ADJ	False	False	False	xxxx	True
# Firmen		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# Restauranten		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# Caféen		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# enger		D	True	False	False	xxxx	True
# zentraler		ADJ	False	False	False	xxxx	True
# Plaz		N	False	False	False	Xxxx	True
# an		APPR	True	False	False	xx	True
# engem		D	True	False	False	xxxx	True
# ënnerierdesche		ADJ	False	False	False	xxxx	True
# Parkhaus		N	False	False	False	Xxxxx	True
# .		$	False	True	False	.	False
# Déi		D	True	False	False	Xxx	True
N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# d'		D	True	False	False	x'	False
# Gebléishal		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# d'		D	True	False	False	x'	False
# Lager		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# dat		P	True	False	False	xxx	True
# fréiert		V	False	False	False	xxxx	True
# Stellwierk		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# sou		AV	True	False	False	xxx	True
# wéi		KO	True	False	False	xxx	True
# déi		D	True	False	False	xxx	True
# al		ADJ	False	False	False	xx	True
# stenge		ADJ	False	False	False	xxxx	True
# Mauer		N	False	False	False	Xxxxx	True
# laanscht		APPR	False	False	False	xxxx	True
# d'		D	True	False	False	x'	False
# Rue		N	False	False	False	Xxx	True
# d'		D	True	False	False	x'	False
# Audun		N	False	False	False	Xxxxx	True
# .		$	False	True	False	.	False
# RTL		N	False	False	False	XXX	True
# NEWS		N	False	False	False	XXXX	True
# :		$	False	True	False	:	False
# De		D	True	False	False	Xx	True
# Projet		N	False	False	False	Xxxxx	True
# gouf		AUX	True	False	False	xxxx	True
# virgestallt		V	False	False	False	xxxx	True
# .		$	False	True	False	.	False
# Den		D	True	False	False	Xxx	True
# neie		ADJ	False	False	False	xxxx	True
# Quartier		N	False	False	False	Xxxxx	True
# soll		MV	False	False	False	xxxx	True
# och		AV	True	False	False	xxx	True
# eng		D	True	False	False	xxx	True
# Verbindung		N	False	False	False	Xxxxx	True
# sinn		AUX	True	False	False	xxxx	True
# tëscht		APPR	True	False	False	xxxx	True
# der		D	True	False	False	xxx	True
# Brillplaz		N	False	False	False	Xxxxx	True
# an		APPR	True	False	False	xx	True
# der		D	True	False	False	xxx	True
# Hiel		N	False	False	False	Xxxx	True
# .		$	False	True	False	.	False
# D'		D	True	False	False	X'	False
# Suitte		N	False	False	False	Xxxxx	True
# vum		APPRART	True	False	False	xxx	True
# Projet		N	False	False	False	Xxxxx	True
# op		APPR	True	False	False	xx	True
# d'		D	True	False	False	x'	False
# Ëmwelt		N	False	False	False	Xxxxx	True
# sollen		MV	False	False	False	xxxx	True
# esou		AV	True	False	False	xxxx	True
# kleng		ADJ	False	False	False	xxxx	True
# wéi		KO	True	False	False	xxx	True
# méiglech		ADJ	False	False	False	xxxx	True
# bleiwen		V	False	False	False	xxxx	True
# ,		$	False	True	False	,	False
# deemno		AV	False	False	False	xxxx	True
# gëtt		AUX	True	False	False	xxxx	True
# d'		D	True	False	False	x'	False
# Bebauung		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# wat		P	True	False	False	xxx	True
# méi		AV	True	False	False	xxx	True
# no		APPR	True	False	False	xx	True
# bei		APPR	True	False	False	xxx	True
# Gréngflächen		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# och		AV	True	False	False	xxx	True
# manner		P	False	False	False	xxxx	True
# dicht		ADJ	False	False	False	xxxx	True
# .		$	False	True	False	.	False
# Ressource		N	False	False	False	Xxxxx	True
# wéi		KO	True	False	False	xxx	True
# Energie		N	False	False	False	Xxxxx	True
# a		KO	True	False	False	x	True
# Waasser		N	False	False	False	Xxxxx	True
# solle		MV	False	False	False	xxxx	True
# mat		APPR	True	False	False	xxx	True
# Hëllef		N	False	False	False	Xxxxx	True
# vu		APPR	True	False	False	xx	True
# modernen		ADJ	False	False	False	xxxx	True
# Technologië		N	False	False	False	Xxxxx	True
# verwalt		V	False	False	False	xxxx	True
# ginn		AUX	True	False	False	xxxx	True
# .		$	False	True	False	.	False
# En		D	True	False	False	Xx	True
# Zäitraum		N	False	False	False	Xxxxx	True
# fir		APPR	True	False	False	xxx	True
# de		D	True	False	False	xx	True
# Projet		N	False	False	False	Xxxxx	True
# gëtt		AUX	True	False	False	xxxx	True
# et		P	True	False	False	xx	True
# nach		AV	True	False	False	xxxx	True
# net		PTK	True	False	False	xxx	True
# .		$	False	True	False	.	False
# Eleng		AV	False	False	False	Xxxxx	True
# beim		APPRART	True	False	False	xxxx	True
# Ëmsetze		N	False	False	False	Xxxxx	True
# vum		APPRART	True	False	False	xxx	True
# komplette		ADJ	False	False	False	xxxx	True
# Projet		N	False	False	False	Xxxxx	True
# gëtt		AUX	True	False	False	xxxx	True
# mat		APPR	True	False	False	xxx	True
# engem		D	True	False	False	xxxx	True
# Zäitraum		N	False	False	False	Xxxxx	True
# vu		APPR	True	False	False	xx	True
# 15		NUM	False	False	False	dd	False
# Joer		N	False	False	False	Xxxx	True
# gerechent		V	False	False	False	xxxx	True
# .		$	False	True	False	.	False
# Gebaut		N	False	False	False	Xxxxx	True
# gëtt		AUX	True	False	False	xxxx	True
# an		KO	True	False	False	xx	True
# Etappen		N	False	False	False	Xxxxx	True
# ,		$	False	True	False	,	False
# woubäi		ADJ	False	False	False	xxxx	True
# deen		D	True	False	False	xxxx	True
# Deel		N	True	False	False	Xxxx	True
# ,		$	False	True	False	,	False
# dee		P	True	False	False	xxx	True
# méi		AV	True	False	False	xxx	True
# no		APPR	True	False	False	xx	True
# beim		APPRART	True	False	False	xxxx	True
# Zentrum		N	False	False	False	Xxxxx	True
# läit		V	False	False	False	xxxx	True
# ,		$	False	True	False	,	False
# den		D	True	False	False	xxx	True
# Ufank		N	False	False	False	Xxxxx	True
# mécht		V	True	False	False	xxxx	True
# .		$	False	True	False	.	False

# %% [markdown]
# # Todos
#
# - tokenisation of the frequent cliticisation of definite article *d'* with the following noun: At the moment this combination is still treated as one word, e.g. *d'Kanner*. However, all *d'*s have to be tokenised as isolated words, i.e. *[d'] [Kanner]*
# - write tokoenisation exception rules for multi-token words, e.g. *op d'mannst, fir d'éischt*
# - enlarge the lists for abbreviations
# - find a way to deal with the tremendous amount of spelling variation for Luxembourgish, which although a standardised spelling exists, is written in zillions of different ways. Common spelling variants could be integrated into the exception lists, e.g.
# - improve the language model (more POS training data, syntactic annotations etc.)
# - integrate NER
# - integrate word vectors

# %% [markdown]
# @PeterGilles, Allerhellegen 2019, Updated 20.7.2023
