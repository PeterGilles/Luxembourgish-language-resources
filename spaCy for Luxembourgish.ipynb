# %% [markdown]
# # Using spaCy for Luxembourgish
#
# Since spaCy version 2.2.2 basic support for Luxembourgish (lb) has been implemented.
#
# This notebook illustrates a few examples and
# So far, the following basic functions should work:
#
#  - tokenisation
#  - lemmatisation
#  - POS tagging (language model needed)

# %%
# install spaCy (>= 2.2.2)
# python -m pip install -U spacy

# install spacy-lookup-data (needed for lemmatisation; Luxembourgish lemmatisation data is included)
# python -m pip install -U spacy-lookups-data

# %%
import spacy
from spacy import lang
# you need spaCy version >= 2.2.2
from spacy.lang.lb import Luxembourgish

# %% [markdown]
# ## Basic tokenisation

# %%
# Create the nlp object
nlp = Luxembourgish()

# Process a text
doc = nlp("fänke mer mam groupsspapp un, e grousspapp ass ëmmer e gudden ufank.")

# list tokens + token index
for token in doc:
    print('"' + token.text + '"', token.idx)
# Out:
# "fänke" 0
# "mer" 6
# "mam" 10
# "groupsspapp" 14
# "un" 26
# "," 28
# "e" 30
# "grousspapp" 32
# "ass" 43
# "ëmmer" 47
# "e" 53
# "gudden" 55
# "ufank" 62
# "." 67

# %% [markdown]
# ## POS tagging and further annotation
#
# In order to use POS tagging, a language model is needed. spaCy is not yet providing a model for Luxembourgish (see [link here] (https://spacy.io/usage/training) on how to train custom models). In the meantime, I've trained an own model, which can be downloaded [link here](http://engelmann.uni.lu/temp/lb_model.zip).

# %%
# unzip lb_model.zip and reference the 'model-best' folder in 'spacy.load'
# load the language model
nlp = spacy.load("lb_model/model-best/")

# %%
# some Luxembourgish example texts to play with the POS tagging
doc = nlp(u"Zanter 1977 gëtt den Terrain vun der \"Lentille Terres Rouges\" net méi exploitéiert. De Projet \"Rout Lëns\" soll dem Site neit Liewen anhauchen. Zu Esch soll tëscht der Rue d'Audun an der Rue Barbourg en neie Quartier entstoe mat Wunnengen, Büroen, Butteker, klenge Firmen, Restauranten, Caféen, enger zentraler Plaz an engem ënnerierdesche Parkhaus. Déi historesch Valeur vum Site soll dobäi net zerstéiert ginn. Op ronn 11 Hektar soll de Quartier \"Rout Lëns\" en neien Espace public mat ville Gréngfläche ginn, dee Commerce, Schaffen a Liewe matenee verbënnt. A well dat Ganzt am Respekt an der Valorisatioun vun der industrieller Patrimoine soll entstoen, solle verschidden al Gebaier och net ofgerappt, mä bestoe bleiwen an an de Projet integréiert ginn. Erhale bleiwen déi al Turbinnenhal, d'Gebléishal, d'Lager, dat fréiert Stellwierk, sou wéi déi al stenge Mauer laanscht d'Rue d'Audun. RTL NEWS: De Projet gouf virgestallt. Den neie Quartier soll och eng Verbindung sinn tëscht der Brillplaz an der Hiel. D'Suitte vum Projet op d'Ëmwelt sollen esou kleng wéi méiglech bleiwen, deemno gëtt d'Bebauung, wat méi no bei Gréngflächen, och manner dicht. Ressource wéi Energie a Waasser solle mat Hëllef vu modernen Technologië verwalt ginn. En Zäitraum fir de Projet gëtt et nach net. Eleng beim Ëmsetze vum komplette Projet gëtt mat engem Zäitraum vu 15 Joer gerechent. Gebaut gëtt an Etappen, woubäi deen Deel, dee méi no beim Zentrum läit, den Ufank mécht.")
#doc = nlp(u"Ech fannen et net normal wann Leit dei schon‘s esou laang hei liewen keen Letzebuergesch schwetzen, si kreien dei Letzebuergesch Nationaliteit, a schwetzen net eis Sprooch, a wou get et dat soss an Europa. Kann ech nemmen de Kapp reselen. Wann ech an engem aneren Land liewen, passen ech mech un. Lescht war ech an engem Supermarché an du soutz een aus dem Orient an der Keiss, ech war positiv iwwerrascht, hien huet gudd eis Sprooch geschwaat, hien wier erreicht 3 Joer hei am Land. Ech hun dei Persoun missten luewen (wat ech dann emmer maachen) hien geif an Oweskueren goen, all mein Respekt, et geet dach, wann een well. An Frontalien brengen et mol net ferdeg Moien an Äddi ze soen, dat nennen ech, keen Respekt, si verdingen jo schliesslech hiert Geld hei.")
#doc = nlp(u"Majo! Ech mengen emol,domat hat t'CSV nëtt esou richtég gerechent. T'Sach ass einfach : t'CSV kann nëmmen an t'Regierung,wann een vun denen drei déi bis elo an der Regierung waren mat der CSV zesummen gét. Sollten DP,LSAP an déi Grëng séch eens ginn,weider 5 Johr drun ze hänken,dann hun sie mat 31 Sëtzer t'Majoritéit an t'CSV dirf dann nach weider 5 Johr an t'Oppositioun. Ech sinn emol gespant wéi dat do aus gét. Ann schons sinn mier nees beim Wielerwellen. Ech gesinn dass LSAP massiv verluer hued ann ‘DP mamm Premierbonus keen iwerzeegend Resultaat haat .Ann dann ass nach doo och nach schlisslech d’Zuel vunn den Setz.")
#doc = nlp(u"Am Schlass hieft Fuuss de Schwänzchen / Sou riicht als wi e Poul, / Geet matzen duerch seng Feinden / Eeriicht zum Kinneksstoul. // E setzt sech duer op d'Knéien, / De Kinnek kuckt ewech. / De Fuuss fängt un ze léien, / An all Äbléck méi frech: / Här Kinnek, kënnt dir liesen / Op jéidem senger Stir, / A stéing hir Schold / Geschriwwenop allen hirer dir; / Kënnt dir an d'Häerzer kucken / Wi an eng Wisebaach: / Da kéim elo meng Onschold / Hei huerteg un den Dag.")
#doc = nlp(u"Waat wells de machen. Den ganzen commerce sekteur get vun den frontaliers iwerholl. An zwar net nemmen Arbechtskraft, vill Patron machen Geschäfter op. Wei bei mir, ugefaangen mat engem klengen Geschäft virun Joeren, daat war gudd gangen, dunn en zweet an en drett. Arbeschter waren frontaliers mee och Letzebuerger. (Wahrscheinlech kruut en Geld vum Staat) elo as daat fenneft geschäft opgemacht gin, an et schafft juste nach een Letzebuerger do, an zwar sin ech daat. Den Recht alles nemmen frontaliers, dei och eng aaner Religioun hun🤔🤬. An esou as daat iwerall esoulues. Ech fannen daat perséinlech guer net méi gut.")

# %%
# print results from POS tagging
# token   lemma    POS   punct?   space?   shape

for token in doc:
    print("{0}\t{1}\t{2}\t{3}\t{4}\t{5}".format(
        token.text,
        token.lemma_,
        token.tag_,
        token.is_punct,
        token.is_space,
        token.shape_
    ))
# Out:
# Zanter	Zanter	N	False	False	Xxxxx
# 1977	1977	NUM	False	False	dddd
# gëtt	ginn	AUX	False	False	xxxx
# den	den	D	False	False	xxx
# Terrain	Terrain	N	False	False	Xxxxx
# vun	vun	APPR	False	False	xxx
# der	der	D	False	False	xxx
# "	"	$	True	False	"
# Lentille	Lentille	N	False	False	Xxxxx
# Terres	Terres	N	False	False	Xxxxx
# Rouges	Rouges	N	False	False	Xxxxx
# "	"	$	True	False	"
# net	net	PTK	False	False	xxx
# méi	méi	AV	False	False	xxx
# exploitéiert	exploitéieren	V	False	False	xxxx
# .	.	$	True	False	.
# De	De	D	False	False	Xx
# Projet	Projet	N	False	False	Xxxxx
# "	"	$	True	False	"
# Rout	Rout	N	False	False	Xxxx
# Lëns	Lëns	N	False	False	Xxxx
# "	"	$	True	False	"
# soll	sollen	MV	False	False	xxxx
# dem	dem	D	False	False	xxx
# Site	Site	N	False	False	Xxxx
# neit	nei	ADJ	False	False	xxxx
# Liewen	Liewen	N	False	False	Xxxxx
# anhauchen	anhauchen	V	False	False	xxxx
# .	.	$	True	False	.
# Zu	Zu	APPR	False	False	Xx
# Esch	Esch	N	False	False	Xxxx
# soll	sollen	MV	False	False	xxxx
# tëscht	tëscht	APPR	False	False	xxxx
# der	der	D	False	False	xxx
# Rue	Rue	N	False	False	Xxx
# d'Audun	d'Audun	APPR	False	False	x'Xxxxx
# an	an	APPR	False	False	xx
# der	der	D	False	False	xxx
# Rue	Rue	N	False	False	Xxx
# Barbourg	Barbourg	N	False	False	Xxxxx
# en	en	D	False	False	xx
# neie	nei	ADJ	False	False	xxxx
# Quartier	Quartier	N	False	False	Xxxxx
# entstoe	entstoen	V	False	False	xxxx
# mat	mat	APPR	False	False	xxx
# Wunnengen	Wunneng	N	False	False	Xxxxx
# ,	,	$	True	False	,
# Büroen	Büro	N	False	False	Xxxxx
# ,	,	$	True	False	,
# Butteker	Buttek	N	False	False	Xxxxx
# ,	,	$	True	False	,
# klenge	kleng	ADJ	False	False	xxxx
# Firmen	Firma	N	False	False	Xxxxx
# ,	,	$	True	False	,
# Restauranten	Restaurant	N	False	False	Xxxxx
# ,	,	$	True	False	,
# Caféen	Café	N	False	False	Xxxxx
# ,	,	$	True	False	,
# enger	enger	D	False	False	xxxx
# zentraler	zentral	ADJ	False	False	xxxx
# Plaz	Plaz	N	False	False	Xxxx
# an	an	APPR	False	False	xx
# engem	engem	D	False	False	xxxx
# ënnerierdesche	ënnerierdesch	ADJ	False	False	xxxx
# Parkhaus	Parkhaus	N	False	False	Xxxxx
# .	.	$	True	False	.
# Déi	Déi	D	False	False	Xxx
# historesch	historesch	ADJ	False	False	xxxx
# Valeur	Valeur	N	False	False	Xxxxx
# vum	vum	APPRART	False	False	xxx
# Site	Site	N	False	False	Xxxx
# soll	sollen	MV	False	False	xxxx
# dobäi	dobäi	AV	False	False	xxxx
# net	net	PTK	False	False	xxx
# zerstéiert	zerstéieren	V	False	False	xxxx
# ginn	goen	AUX	False	False	xxxx
# .	.	$	True	False	.
# Op	Op	APPR	False	False	Xx
# ronn	ronnen	AV	False	False	xxxx
# 11	11	NUM	False	False	dd
# Hektar	Hektar	N	False	False	Xxxxx
# soll	sollen	MV	False	False	xxxx
# de	den	D	False	False	xx
# Quartier	Quartier	N	False	False	Xxxxx
# "	"	$	True	False	"
# Rout	Rout	N	False	False	Xxxx
# Lëns	Lëns	N	False	False	Xxxx
# "	"	$	True	False	"
# en	en	D	False	False	xx
# neien	nei	ADJ	False	False	xxxx
# Espace	Espace	N	False	False	Xxxxx
# public	public	ADJ	False	False	xxxx
# mat	mat	APPR	False	False	xxx
# ville	vill	P	False	False	xxxx
# Gréngfläche	Gréngfläch	N	False	False	Xxxxx
# ginn	goen	AUX	False	False	xxxx
# ,	,	$	True	False	,
# dee	deen	D	False	False	xxx
# Commerce	Commerce	N	False	False	Xxxxx
# ,	,	$	True	False	,
# Schaffen	Schaff	N	False	False	Xxxxx
# a	an	KO	False	False	x
# Liewe	Liewen	N	False	False	Xxxxx
# matenee	mateneen	ADJ	False	False	xxxx
# verbënnt	verbannen	V	False	False	xxxx
# .	.	$	True	False	.
# A	A	KO	False	False	X
# well	well	KO	False	False	xxxx
# dat	dat	D	False	False	xxx
# Ganzt	Ganzt	N	False	False	Xxxxx
# am	am	APPRART	False	False	xx
# Respekt	Respekt	N	False	False	Xxxxx
# an	an	APPR	False	False	xx
# der	der	D	False	False	xxx
# Valorisatioun	Valorisatioun	N	False	False	Xxxxx
# vun	vun	APPR	False	False	xxx
# der	der	D	False	False	xxx
# industrieller	industriell	ADJ	False	False	xxxx
# Patrimoine	Patrimoine	N	False	False	Xxxxx
# soll	sollen	MV	False	False	xxxx
# entstoen	entstoen	V	False	False	xxxx
# ,	,	$	True	False	,
# solle	sollen	MV	False	False	xxxx
# verschidden	verschidden	ADJ	False	False	xxxx
# al	al	ADJ	False	False	xx
# Gebaier	Gebai	N	False	False	Xxxxx
# och	och	PTK	False	False	xxx
# net	net	PTK	False	False	xxx
# ofgerappt	ofgerappt	V	False	False	xxxx
# ,	,	$	True	False	,
# mä	mä	KO	False	False	xx
# bestoe	bestoen	ADJ	False	False	xxxx
# bleiwen	bleiwen	V	False	False	xxxx
# an	an	KO	False	False	xx
# an	an	APPR	False	False	xx
# de	den	D	False	False	xx
# Projet	Projet	N	False	False	Xxxxx
# integréiert	integréieren	V	False	False	xxxx
# ginn	goen	AUX	False	False	xxxx
# .	.	$	True	False	.
# Erhale	Erhale	N	False	False	Xxxxx
# bleiwen	bleiwen	V	False	False	xxxx
# déi	déi	D	False	False	xxx
# al	al	ADJ	False	False	xx
# Turbinnenhal	Turbinnenhal	N	False	False	Xxxxx
# ,	,	$	True	False	,
# d'Gebléishal	d'Gebléishal	P	False	False	x'Xxxxx
# ,	,	$	True	False	,
# d'Lager	d'Lager	P	False	False	x'Xxxxx
# ,	,	$	True	False	,
# dat	dat	P	False	False	xxx
# fréiert	fréieren	V	False	False	xxxx
# Stellwierk	Stellwierk	N	False	False	Xxxxx
# ,	,	$	True	False	,
# sou	sou	AV	False	False	xxx
# wéi	wéien	KO	False	False	xxx
# déi	déi	D	False	False	xxx
# al	al	ADJ	False	False	xx
# stenge	stengen	ADJ	False	False	xxxx
# Mauer	Mauer	N	False	False	Xxxxx
# laanscht	laanscht	APPR	False	False	xxxx
# d'Rue	d'Rue	D	False	False	x'Xxx
# d'Audun	d'Audun	NUM	False	False	x'Xxxxx
# .	.	$	True	False	.
# RTL	Rtl	N	False	False	XXX
# NEWS	NEWS	N	False	False	XXXX
# :	:	$	True	False	:
# De	De	D	False	False	Xx
# Projet	Projet	N	False	False	Xxxxx
# gouf	ginn	AUX	False	False	xxxx
# virgestallt	virgestallt	V	False	False	xxxx
# .	.	$	True	False	.
# Den	Den	D	False	False	Xxx
# neie	nei	ADJ	False	False	xxxx
# Quartier	Quartier	N	False	False	Xxxxx
# soll	sollen	MV	False	False	xxxx
# och	och	AV	False	False	xxx
# eng	engen	D	False	False	xxx
# Verbindung	Verbindung	N	False	False	Xxxxx
# sinn	sinn	AUX	False	False	xxxx
# tëscht	tëscht	APPR	False	False	xxxx
# der	der	D	False	False	xxx
# Brillplaz	Brillplaz	N	False	False	Xxxxx
# an	an	APPR	False	False	xx
# der	der	D	False	False	xxx
# Hiel	Hiel	N	False	False	Xxxx
# .	.	$	True	False	.
# D'Suitte	D'Suitte	V	False	False	X'Xxxxx
# vum	vum	APPRART	False	False	xxx
# Projet	Projet	N	False	False	Xxxxx
# op	op	APPR	False	False	xx
# d'Ëmwelt	d'Ëmwelt	V	False	False	x'Xxxxx
# sollen	sollen	MV	False	False	xxxx
# esou	esou	AV	False	False	xxxx
# kleng	kleng	ADJ	False	False	xxxx
# wéi	wéien	KO	False	False	xxx
# méiglech	méiglech	ADJ	False	False	xxxx
# bleiwen	bleiwen	V	False	False	xxxx
# ,	,	$	True	False	,
# deemno	deemno	AV	False	False	xxxx
# gëtt	ginn	AUX	False	False	xxxx
# d'Bebauung	d'Bebauung	AV	False	False	x'Xxxxx
# ,	,	$	True	False	,
# wat	wat	P	False	False	xxx
# méi	méi	AV	False	False	xxx
# no	no	APPR	False	False	xx
# bei	bei	APPR	False	False	xxx
# Gréngflächen	Gréngfläch	N	False	False	Xxxxx
# ,	,	$	True	False	,
# och	och	PTK	False	False	xxx
# manner	manner	ADJ	False	False	xxxx
# dicht	dichten	N	False	False	xxxx
# .	.	$	True	False	.
# Ressource	Ressource	N	False	False	Xxxxx
# wéi	wéien	KO	False	False	xxx
# Energie	Energie	N	False	False	Xxxxx
# a	an	KO	False	False	x
# Waasser	Waasser	N	False	False	Xxxxx
# solle	sollen	MV	False	False	xxxx
# mat	mat	APPR	False	False	xxx
# Hëllef	Hëllef	N	False	False	Xxxxx
# vu	vun	APPR	False	False	xx
# modernen	modern	ADJ	False	False	xxxx
# Technologië	Technologie	N	False	False	Xxxxx
# verwalt	verwalten	V	False	False	xxxx
# ginn	goen	AUX	False	False	xxxx
# .	.	$	True	False	.
# En	En	D	False	False	Xx
# Zäitraum	Zäitraum	N	False	False	Xxxxx
# fir	fir	APPR	False	False	xxx
# de	den	D	False	False	xx
# Projet	Projet	N	False	False	Xxxxx
# gëtt	ginn	AUX	False	False	xxxx
# et	et	P	False	False	xx
# nach	nach	AV	False	False	xxxx
# net	net	PTK	False	False	xxx
# .	.	$	True	False	.
# Eleng	Eleng	AV	False	False	Xxxxx
# beim	beim	APPRART	False	False	xxxx
# Ëmsetze	Ëmsetze	N	False	False	Xxxxx
# vum	vum	APPRART	False	False	xxx
# komplette	komplett	ADJ	False	False	xxxx
# Projet	Projet	N	False	False	Xxxxx
# gëtt	ginn	AUX	False	False	xxxx
# mat	mat	APPR	False	False	xxx
# engem	engem	D	False	False	xxxx
# Zäitraum	Zäitraum	N	False	False	Xxxxx
# vu	vun	APPR	False	False	xx
# 15	15	NUM	False	False	dd
# Joer	Joer	N	False	False	Xxxx
# gerechent	gerechent	V	False	False	xxxx
# .	.	$	True	False	.
# Gebaut	Gebaut	N	False	False	Xxxxx
# gëtt	ginn	AUX	False	False	xxxx
# an	an	KO	False	False	xx
# Etappen	Etapp	N	False	False	Xxxxx
# ,	,	$	True	False	,
# woubäi	woubäi	AV	False	False	xxxx
# deen	deen	D	False	False	xxxx
# Deel	Deel	N	False	False	Xxxx
# ,	,	$	True	False	,
# dee	deen	P	False	False	xxx
# méi	méi	AV	False	False	xxx
# no	no	APPR	False	False	xx
# beim	beim	APPRART	False	False	xxxx
# Zentrum	Zentrum	N	False	False	Xxxxx
# läit	leien	V	False	False	xxxx
# ,	,	$	True	False	,
# den	den	D	False	False	xxx
# Ufank	Ufank	N	False	False	Xxxxx
# mécht	maachen	V	False	False	xxxx
# .	.	$	True	False	.

# %% [markdown]
# # Todos
#
# - tokenisation of the frequent cliticisation of definite article *d'* with the following noun: At the moment this combination is still treated as one word, e.g. *d'Kanner*. However, all *d'*s have to be tokenised as isolated words, i.e. *[d'] [Kanner]*
# - write tokoenisation exception rules for multi-token words, e.g. *op d'mannst, fir d'éischt*
# - enlarge the lists for abbreviations
# - find a way to deal with the tremendous amount of spelling variation for Luxembourgish, which although a standardised spelling exists, is written in zillions of different ways. Common spelling variants could be integrated into the exception lists, e.g.
# - improve the language model (more POS training data, syntactic annotations etc.)
# - integrate NER
# - integrate word vectors

# %% [markdown]
# @PeterGilles, Allerhellegen 2019
