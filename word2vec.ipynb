# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
import numpy
import gensim
import os
import codecs
import io
import tensorflow as tf
import numpy as np
from sklearn.manifold import TSNE
from sklearn.datasets import fetch_20newsgroups
import re
import matplotlib.pyplot as plt

class MySentences(object):
    def __init__(self, dirname):
        self.dirname = dirname
 
    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                yield line.split()
 
sentences = MySentences('/Users/peter.gilles/LOD-training') # a memory-friendly iterator
# Out:
# 2017-10-26 10:01:40,225 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
model = gensim.models.Word2Vec(sentences, min_count=2)
# Out:
# 2017-10-22 17:09:42,842 : INFO : collecting all words and their counts
# 2017-10-22 17:09:42,843 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-10-22 17:09:43,066 : INFO : PROGRESS: at sentence #10000, processed 581092 words, keeping 74026 word types
# 2017-10-22 17:09:43,114 : INFO : PROGRESS: at sentence #20000, processed 682880 words, keeping 77996 word types
# 2017-10-22 17:09:43,157 : INFO : PROGRESS: at sentence #30000, processed 783850 words, keeping 81344 word types
# 2017-10-22 17:09:43,198 : INFO : PROGRESS: at sentence #40000, processed 886261 words, keeping 84775 word types
# 2017-10-22 17:09:43,243 : INFO : PROGRESS: at sentence #50000, processed 987103 words, keeping 88106 word types
# 2017-10-22 17:09:43,288 : INFO : PROGRESS: at sentence #60000, processed 1090449 words, keeping 90671 word types
# 2017-10-22 17:09:43,329 : INFO : PROGRESS: at sentence #70000, processed 1192539 words, keeping 92986 word types
# ...

# %%
# save the model
model.save("LUXmodel")
# Out:
# 2017-10-22 17:23:28,362 : INFO : saving Word2Vec object under LUXmodel, separately None
# 2017-10-22 17:23:28,363 : INFO : storing np array 'syn0' to LUXmodel.wv.syn0.npy
# 2017-10-22 17:23:29,459 : INFO : not storing attribute syn0norm
# 2017-10-22 17:23:29,460 : INFO : storing np array 'syn1neg' to LUXmodel.syn1neg.npy
# 2017-10-22 17:23:30,358 : INFO : not storing attribute cum_table
# 2017-10-22 17:23:34,363 : INFO : saved LUXmodel

# %%
# load the model
model = gensim.models.Word2Vec.load("LUXmodel")
# Out:
# 2017-10-26 10:01:44,421 : INFO : loading Word2Vec object from LUXmodel
# 2017-10-26 10:01:48,574 : INFO : loading wv recursively from LUXmodel.wv.* with mmap=None
# 2017-10-26 10:01:48,575 : INFO : loading syn0 from LUXmodel.wv.syn0.npy with mmap=None
# 2017-10-26 10:01:49,146 : INFO : setting ignored attribute syn0norm to None
# 2017-10-26 10:01:49,147 : INFO : loading syn1neg from LUXmodel.syn1neg.npy with mmap=None
# 2017-10-26 10:01:49,654 : INFO : setting ignored attribute cum_table to None
# 2017-10-26 10:01:49,655 : INFO : loaded LUXmodel

# %%
model.most_similar(['Molzecht'] , topn=20)
# Out:
# [('Moolzecht', 0.8024662733078003),
#  ('geldstroff', 0.7859477400779724),
#  ('Zerwéit', 0.7851787805557251),
#  ('Drëpp', 0.7769683599472046),
#  ('Schlupp', 0.7751361131668091),
#  ('Sonnenfinsternis', 0.7696055173873901),
#  ('Uelegmillen', 0.7695586085319519),
#  ('Kasematt', 0.7673219442367554),
#  ('rés', 0.766385555267334),
#  ('Liewensmëttelvergëftung', 0.7651002407073975),
#  ('Nobildung', 0.7650794386863708),
#  ('Terass', 0.7621920108795166),
#  ('Rieseschlang', 0.7616627812385559),
#  ('Kladder', 0.758621096611023),
#  ('Tas', 0.7581988573074341),
#  ('Schongkëscht', 0.7578831911087036),
#  ('Zäitfënster', 0.7540919184684753),
#  ('Chipkaart', 0.7539894580841064),
#  ('Zooss', 0.7527928352355957),
#  ('Hautkrankheet', 0.7523432970046997)]
